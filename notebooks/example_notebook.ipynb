# %%
import numpy as np
from pfs_obsproc_planning import generatePfsDesign

np.random.seed(1)

# %%
workDir = "../examples/workdir_test"
config = "config.real_targetDB.toml"

n_pccs_l = 5
n_pccs_m = 0
obs_dates = ["2023-10-08", "2023-10-09", "2023-10-10"]

# %%
#
# initialize a GeneratePfsDesign instance
#
gpd = generatePfsDesign.GeneratePfsDesign(config, workDir=workDir)
# Out:
# ../examples/workdir_test/input exists
# ../examples/workdir_test/output/ppp exists
# ../examples/workdir_test/output/qplan exists
# ../examples/workdir_test/cobracoach exists
# ../examples/workdir_test/output/design exists
# pfs_instdata found at ../examples/workdir_test/pfs_instdata, reuse it

# %%
#
# Run PPP
#
gpd.runPPP(n_pccs_l, n_pccs_m, show_plots=True)
# Out:
# ######### Read sample
# #There are     8 proposals loaded.
#   #   24605 targets require the LOW resolution
#   #   15011 targets require the MEDIUM resolution
# ######### Read sample DONE! (takes 0.655 sec)
# ######### Determine pointing centers
# #There are 24605 targets, they are grouped into 9 clusters.
# #There are     5 pointings determined.
# ######### Determine pointing centers DONE! (takes 5.389 sec)
# ######### Start running netflow to assign fibers
# #There are     5 pointings, they are grouped into     2 clusters.
# #Now is Group   1, it contains     4 pointings, and     55 targets.
# Set parameter Presolve to value 1
# Set parameter Method to value 4
# Set parameter DegenMoves to value 0
# Set parameter Heuristics to value 0.8
# Set parameter MIPGap to value 0.01
# Creating network topology
#   exposure 1
# Calculating visibilities
# adding constraints
# adding collision constraints
# adding forbidden pair constraints
#   exposure 2
# Calculating visibilities
# adding constraints
# adding collision constraints
# adding forbidden pair constraints
#   exposure 3
# Calculating visibilities
# adding constraints
# adding collision constraints
# adding forbidden pair constraints
#   exposure 4
# Calculating visibilities
# adding constraints
# adding collision constraints
# adding forbidden pair constraints
# exposure 0:
#   assigned Cobras(%): 1.09%
# exposure 1:
#   assigned Cobras(%): 0.33%
# exposure 2:
#   assigned Cobras(%): 0.33%
# exposure 3:
#   assigned Cobras(%): 0.38%
# #Now is Group   2, it contains     1 pointings, and     18 targets.
# Set parameter Presolve to value 1
# Set parameter Method to value 4
# Set parameter DegenMoves to value 0
# Set parameter Heuristics to value 0.8
# Set parameter MIPGap to value 0.01
# Creating network topology
#   exposure 1
# Calculating visibilities
# adding constraints
# adding collision constraints
# adding forbidden pair constraints
# exposure 0:
#   assigned Cobras(%): 0.63%
# ######### Run netflow DONE! (takes 1.615 sec)
# no allocated time for MR!

# %%
#
# Run qplan
#
# obs_dates = ["2023-12-20", "2023-12-21", "2023-12-22"]
gpd.runQPlan(obs_dates, plotVisibility=True)
# Out:
# {'S24B-QN017': S24B-QN017}
# 42:28:53.89362525314823
# 41:38:27.48590322360201
# 42:48:20.677985849560514
# 42:16:36.56889543995533
# 40:44:43.28182235937618
# Summary_report:
# 100.00 % of schedulable OBs scheduled
# Completed programs
# S24B-QN017     10.00  5/5  1.25/2000.00 hrs
#
# No uncompleted programs
#
# 1 2023-10-08 19:34:08.251871-10:00  Point_L_23344194  00:38:04.697
# 2 2023-10-08 19:49:10.251871-10:00  Point_L_23403118  00:41:31.545
# 3 2023-10-08 20:04:12.251871-10:00  Point_L_23374164  00:40:14.294
# 4 2023-10-08 20:19:14.251871-10:00  Point_L_27429568  00:34:17.116
#
#         ppc_dec
# 0  +42:16:36.57
# 1  +42:28:53.89
# 2  +42:48:20.68
# 3  +41:38:27.49
# 4  +40:44:43.28

# %%
#
# Run SFA
#
gpd.runSFA(clearOutput=True)
# Out:
# 24605
# Point_L_23344194 26
# Point_L_23374164 8
# Point_L_23403118 8
# Point_L_23434880 9
# Point_L_27429568 15
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/notebooks/example_notebook.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bpfsa-usr01-monodera/work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/notebooks/example_notebook.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #
#       <a href='vscode-notebook-cell://ssh-remote%2Bpfsa-usr01-monodera/work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/notebooks/example_notebook.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # Run SFA
#       <a href='vscode-notebook-cell://ssh-remote%2Bpfsa-usr01-monodera/work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/notebooks/example_notebook.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> #
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bpfsa-usr01-monodera/work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/notebooks/example_notebook.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> gpd.runSFA(clearOutput=True)
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/src/pfs_obsproc_planning/generatePfsDesign.py:285, in GeneratePfsDesign.runSFA(self, clearOutput)
#     282 filename = "ppp+qplan_outout.csv"
#     283 df = pd.read_csv(os.path.join(self.outputDirPPP, filename))
# --> 285 listPointings, dictPointings, pfsDesignIds, observation_dates_in_hst = SFA.run(
#     286     self.conf,
#     287     workDir=self.workDir,
#     288     repoDir=self.repoDir,
#     289     clearOutput=clearOutput,
#     290 )
#     292 ## ope file generation ##
#     293 ope = OpeFile(conf=self.conf, workDir=self.workDir)
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/src/pfs_obsproc_planning/SFA.py:19, in run(conf, workDir, repoDir, clearOutput)
#      11 from pfs_design_tool import reconfigure_fibers_ppp as sfa
#      13 infile = os.path.join(workDir, conf["ppp"]["outputDir"], "ppp+qplan_outout.csv")
#      14 (
#      15     list_pointings,
#      16     dict_pointing,
#      17     design_ids,
#      18     observation_dates_in_hst,
# ---> 19 ) = sfa.reconfigure(conf, workDir, infile=infile, clearOutput=clearOutput)
#      21 return list_pointings, dict_pointing, design_ids, observation_dates_in_hst
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pfs_design_tool/reconfigure_fibers_ppp.py:453, in reconfigure(conf, workDir, infile, clearOutput)
#     452 def reconfigure(conf, workDir=".", infile="ppp+qplan_outout.csv", clearOutput=False):
# --> 453     list_pointings, dict_pointings = load_ppp_results(os.path.join(workDir, infile))
#     455     # in_design, df_sci, df_std, df_sky = load_input_design(
#     456     #     args.design_id, indir=args.design_indir, exptime=args.exptime
#     457     # )
#     459     obstime0 = Time("2023-06-15T10:00:00")
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pfs_design_tool/reconfigure_fibers_ppp.py:384, in load_ppp_results(infile)
#     383 def load_ppp_results(infile: str):
# --> 384     df = pd.read_csv(infile)
#     385     # print(df)
#     387     pointings = df["pointing"].unique()
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../examples/workdir_test/../examples/workdir_test/output/ppp/ppp+qplan_outout.csv'
