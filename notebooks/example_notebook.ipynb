# %%
import numpy as np
from pfs_obsproc_planning import generatePfsDesign

np.random.seed(1)

# %%
workDir = "../examples/workdir_test"
config = "config.real_targetDB.toml"

n_pccs_l = 5
n_pccs_m = 0
obs_dates = ["2023-10-08", "2023-10-09", "2023-10-10"]

# %%
#
# initialize a GeneratePfsDesign instance
#
gpd = generatePfsDesign.GeneratePfsDesign(config, workDir=workDir)
# Out:
# ../examples/workdir_test/input exists
# ../examples/workdir_test/output/ppp exists
# ../examples/workdir_test/output/qplan exists
# ../examples/workdir_test/cobracoach exists
# ../examples/workdir_test/output/design exists
# pfs_instdata found at ../examples/workdir_test/pfs_instdata, reuse it

# %%
#
# Run PPP
#
gpd.runPPP(n_pccs_l, n_pccs_m, show_plots=True)
# Out:
# ######### Read sample
# #There are     8 proposals loaded.
#   #   24605 targets require the LOW resolution
#   #   15011 targets require the MEDIUM resolution
# ######### Read sample DONE! (takes 0.937 sec)
# ######### Determine pointing centers
# #There are 24605 targets, they are grouped into 9 clusters.
# #There are     5 pointings determined.
# ######### Determine pointing centers DONE! (takes 5.344 sec)
# ######### Start running netflow to assign fibers
# #There are     5 pointings, they are grouped into     2 clusters.
# #Now is Group   1, it contains     4 pointings, and     55 targets.
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-11-11
# Set parameter Presolve to value 1
# Set parameter Method to value 4
# Set parameter DegenMoves to value 0
# Set parameter Heuristics to value 0.8
# Set parameter MIPGap to value 0.01
# Creating network topology
#   exposure 1
# Calculating visibilities
# adding constraints
# ...

# %%
#
# Run qplan
#
# obs_dates = ["2023-12-20", "2023-12-21", "2023-12-22"]
gpd.runQPlan(obs_dates, plotVisibility=True)
# Out:
# {'S24B-QN017': S24B-QN017}
# 42:28:53.89362525314823
# 41:38:27.48590322360201
# 42:48:20.677985849560514
# 42:16:36.56889543995533
# 40:44:43.28182235937618
# Summary_report:
# 100.00 % of schedulable OBs scheduled
# Completed programs
# S24B-QN017     10.00  5/5  1.25/2000.00 hrs
#
# No uncompleted programs
#
# Total time: avail= 1980.00 sched=   75.17 unsched= 1904.83 min
#
# unschedulable: []
# completed: [{'pgm': S24B-QN017, 'obs': [], 'unschedulable': [], 'obcount': 5, 'sched_time': 4500.0, 'total_time': 7200000.0}]
# uncompleted: []
# 2023-10-08 18:30:00-10:00 2023-10-08 18:30:01-10:00 ob1 None Setup OB: S24B-QN017 Point_L_07931710: 0:34:19.92556053833468 / 42:16:36.56889543995533
# 2023-10-08 18:30:01-10:00 2023-10-08 19:19:06.251871-10:00 ob2 ob2 Delay for Point_L_07931710 visibility
# 2023-10-08 19:19:06.251871-10:00 2023-10-08 19:34:06.251871-10:00 Point_L_07931710 Point_L_07931710 0:34:19.92556053833468 / 42:16:36.56889543995533
# ...

# %%
#
# Run SFA
#
gpd.runSFA(clearOutput=True)
# Out:
# Registering stars for raster scan test.
# Cobras with zero centers: 0
# Cobras with zero link lengths: 0
# Cobras with too long link lengths: 0
# pfs.utils's fiber data directory /work/monodera/Subaru-PFS/pfs_obsproc_planning_tools/.venv/src/pfs-utils/data/fiberids was found and will be used.
# Number of cobras: 2394
# Set parameter Presolve to value 1
# Set parameter Method to value 0
# Set parameter DegenMoves to value 0
# Set parameter Heuristics to value 0.6
# Set parameter MIPGap to value 0.005
# Set parameter PreSOS2Encoding to value 0
# Set parameter PreSOS1Encoding to value 0
# Set parameter Threads to value 4
# Creating network topology
#   exposure 1
# Calculating visibilities
# adding constraints
# adding collision constraints
# adding forbidden pair constraints
# solving the problem
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (linux64)
#
# CPU model: AMD EPYC 7542 32-Core Processor, instruction set [SSE2|AVX|AVX2]
# ...
